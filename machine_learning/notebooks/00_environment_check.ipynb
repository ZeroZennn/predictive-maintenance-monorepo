# %%
import sys
print(sys.executable)
# Out:
# c:\PORTFOLIO\PROJECTS\PBL\Predictive Maintenance\projects\predictive-maintenance-monorepo\machine_learning\venv\Scripts\python.exe

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import seaborn
import plotly
import sklearn
import joblib

# Verifikasi config
sys.path.append('..')
from src.config import (
    SENSOR_FILE, MAINTENANCE_FILE,
    GLOBAL_SEED, W_CRITICAL_HRS, W_WARNING_HRS
)

print("=" * 45)
print("   LAPIS AI — ENVIRONMENT CHECK REPORT")
print("=" * 45)
print(f"  Python      : {sys.version.split()[0]}")
print(f"  Pandas      : {pd.__version__}")
print(f"  NumPy       : {np.__version__}")
print(f"  Matplotlib  : {matplotlib.__version__}")
print(f"  Seaborn     : {seaborn.__version__}")
print(f"  Scikit-learn: {sklearn.__version__}")
print("-" * 45)
print(f"  SENSOR_FILE exists    : {SENSOR_FILE.exists()}")
print(f"  MAINTENANCE_FILE exists: {MAINTENANCE_FILE.exists()}")
print(f"  GLOBAL_SEED           : {GLOBAL_SEED}")
print(f"  W_CRITICAL_HRS        : {W_CRITICAL_HRS}")
print(f"  W_WARNING_HRS         : {W_WARNING_HRS}")
print("=" * 45)
print("  ✅ ENVIRONMENT READY — FASE 0 COMPLETE")
print("=" * 45)
# Out:
# ...
#    LAPIS AI — ENVIRONMENT CHECK REPORT
# ...
#   Python      : 3.10.6
#   Pandas      : 2.2.2
#   NumPy       : 1.26.4
#   Matplotlib  : 3.9.0
#   Seaborn     : 0.13.2
#   Scikit-learn: 1.5.0
# ---------------------------------------------
#   SENSOR_FILE exists    : True
#   MAINTENANCE_FILE exists: True
#   GLOBAL_SEED           : 42
#   W_CRITICAL_HRS        : 24
#   W_WARNING_HRS         : 72
# ...
#   ✅ ENVIRONMENT READY — FASE 0 COMPLETE
# ...
